# %% [markdown]
# # Image Exercise
#
# In the folder "Working with Images" (same folder this notebook is located in) there are two images we will be working with:
# * word_matrix.png
# * mask.png
#
# The word_matrix is a .png image that contains a spreadsheet of words with a hidden message in it. Your task is to use the mask.png image to reveal the hidden message inside the word_matrix.png.

# %%
from PIL import Image

# %%
#open files and assign each image to a name
words = Image.open('word_matrix.png')
mask = Image.open('mask.png')

# %%
type(words)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
#need to ensure the mask image is the same size as the word image
#can check an image size with .size 
words = words.resize((650,325))
words
# Out:
# <PIL.Image.Image image mode=RGBA size=650x325 at 0x24EDFA42880>

# %%
mask = mask.resize((650,325))
mask
# Out:
# <PIL.Image.Image image mode=RGBA size=650x325 at 0x24EDFAC5A90>

# %%
# need to increase transparency of mask image using .putalpha()
mask.putalpha(150)
mask
# Out:
# <PIL.Image.Image image mode=RGBA size=650x325 at 0x24EDFAC5A90>

# %%
words.paste(mask,(0,0),mask)

# %%
words
# Out:
# <PIL.Image.Image image mode=RGBA size=650x325 at 0x24EDFA42880>

# %%
#save words image as message.png
words.save("message.png")

# %%
message = Image.open('message.png')

# %%
message
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=650x325 at 0x24EE19D3AC0>
